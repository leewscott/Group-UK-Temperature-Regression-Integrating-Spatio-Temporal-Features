# %% [markdown]
# # ID5059 Group Project: Temperature Prediction

# %% [markdown]
# ### Modelling: Neural Network
# Want to create a neural network to predict the temperature.

# %%
# import libraries
# load data
from pathlib import Path
import pandas as pd

# pipeline
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer

# modelling and evaluation
import numpy as np
import tensorflow as tf

# sets neural networks to run on gpus if one exist
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)

from tensorflow import keras
from sklearn.model_selection import GridSearchCV
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt
from scipy.stats import binned_statistic

# set seed for numpy
RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)

# %% [markdown]
# #### 1. Load Data
# Loading the data produced by the analysis file.

# %%
# function reads in data from file
def load_data(file_name, file_path = "./", deliniator = ","):
    path = Path() / file_path / file_name; print(path)
    if not path.is_file():
        raise Exception("File not found")

    return pd.read_csv(path, sep = deliniator)
    #return np.loadtxt(path, delimiter = deliniator)

"""
# reads in csv file containing data
file_path = "./"

file_name = "x_train.csv"
x_train = load_data(file_name, file_path = file_path, deliniator = ",")

file_name = "y_train.csv"
y_train = load_data(file_name, file_path = file_path, deliniator = ",")

file_name = "x_valid.csv"
x_valid = load_data(file_name, file_path = file_path, deliniator = ",")

file_name = "y_valid.csv"
y_valid = load_data(file_name, file_path = file_path, deliniator = ",")
"""

# reads in the training and validation sets
file_path = "./"

file_name = "era5_train_prepared_with_no_nearby.csv"
data_train = load_data(file_name, file_path = file_path, deliniator = ",")

file_name = "era5_val_prepared_with_no_nearby.csv"
data_valid = load_data(file_name, file_path = file_path, deliniator = ",")
# Out:
# era5_train_prepared_with_no_nearby.csv
# era5_val_prepared_with_no_nearby.csv

# %%
# printing the heads of the training and validation sets to confirm that they are the same for each model
data_train.head(2)
# Out:
#    latitude  longitude        tp       u10       v10         sp      u100  \
# 0     56.00      -0.75  0.000000  2.117569  8.345276  101296.94  3.671143
# 1     58.75      -5.75  0.000913  5.980820  9.166794  100456.50  8.365173
#
#         v100       tcc  ptype        t2m  year  month  day  hour  season
# 0  10.726196  0.398621    0.0  290.68433  2018      7   31    17       3
# 1  11.827179  1.000000    1.0  287.38440  2018      8   21    20       3

# %%
data_valid.head(2)
# Out:
#    latitude  longitude        tp       u10       v10         sp      u100  \
# 0     51.25      -7.25  0.000000  5.886337 -0.648453  101456.50  6.440597
# 1     52.50      -3.75  0.000005 -4.333618  1.897888   99209.44 -7.078690
#
#        v100       tcc  ptype       t2m  year  month  day  hour  season
# 0 -0.707596  0.025299    0.0  283.5376  2018      5   13     4       2
# 1  3.492432  1.000000    1.0  283.2859  2018     11   16    22       4

# %% [markdown]
# #### 2. Pipeline to convert to numpy for keras
# Want to make data into numpy array for compatibility with keras. Also want to scale numeric attributes to improve neural network performance.

# %%
# pipeline included to convert the dataset from pandas to numpy for keras compatibility
one_hot_columns = ["year", "month", "day", "hour", "season", "ptype"]
all_columns = data_train.loc[:, data_train.columns != "t2m"].columns

"""
datetime_pipeline = Pipeline([
    ("extract_datetime", FunctionTransformer(extract_datetime_features, validate=False)),
    ("one_hot_encode", OneHotEncoder(handle_unknown="ignore", sparse_output = False))
])
"""

# deals with numeric attributes
# want to scale numeric attributes to improve neural network performance
numeric_pipeline = Pipeline([
    ("impute", SimpleImputer()),
    ("scale", StandardScaler())
])

preprocessor = ColumnTransformer([
    #("datetime", datetime_pipeline, ["valid_time"]),
    #("encode_ptype", OneHotEncoder(handle_unknown="ignore", sparse_output = False), ["ptype"]),
    ("encode data", OneHotEncoder(handle_unknown="ignore", sparse_output = False), one_hot_columns),
    ("numeric", numeric_pipeline, all_columns)
    #("drop_columns", "drop", columns_to_drop)
], remainder = "drop", 
sparse_threshold = 0.0
)

full_pipeline = Pipeline([
    ("preprocess", preprocessor)
])

# separating the response variable before using the pipeline on the training and validation sets
y_train = data_train["t2m"].to_numpy()
y_valid = data_valid["t2m"].to_numpy()

# using the pipeline on the training and validation sets
x_train = full_pipeline.fit_transform(data_train.drop("t2m", axis = 1))
x_valid = full_pipeline.transform(data_valid.drop("t2m", axis = 1))

# %%
# checks to ensure that all of the data types are compatible for use in modelling
type(x_train) == type(x_valid) == type(y_train) == type(y_valid)
# Out:
# True

# %% [markdown]
# #### 3. Implement Neural Network
# Create the neural network.

# %%
# current version of tensor flow incompatible with version of python agreed upon in group contract
# hence no R2 function
# hence manual implementation

# calculates the R2 score
@keras.utils.register_keras_serializable()
def R2(yTrue, yPredicted):
    residual = keras.backend.sum( (yTrue - yPredicted) ** 2 )
    total = keras.backend.sum( (yTrue - keras.backend.mean(yTrue)) ** 2 )
    return 1 - (residual / ( total + keras.backend.epsilon() ))

# %%
# creates a function to define the neural network so that it can be used in a grid search
def create_neural_network(learning_rate=0.001):
    model = keras.models.Sequential()
    model.add( keras.layers.Dense(24, input_shape = (x_train.shape[1], ), activation = "relu",
                                  kernel_regularizer = keras.regularizers.L1L2(l1 = 0.01 , l2 = 0.01))
                                  )
    model.add( keras.layers.Dense(16, activation = "relu",
                                  kernel_regularizer = keras.regularizers.L1L2(l1 = 0.01 , l2 = 0.01))
                                  )
    model.add( keras.layers.Dense(8, activation = "relu",
                                  kernel_regularizer = keras.regularizers.L1L2(l1 = 0.01 , l2 = 0.01))
                                  )
    model.add( keras.layers.Dense(1, activation = "linear") )

    model.compile(loss = "mse",
                  optimizer = keras.optimizers.Adam(learning_rate, beta_1 = 0.9, beta_2 = 0.999, epsilon = 1e-07),
                  metrics = [keras.metrics.MeanSquaredError(), R2] )
    return model

# %% [markdown]
# #### 4. Grid Search for Optimal Hyperparameters
# Want to find best hyperparameters to improve model performance.

# %%
# run grid search on cpu to save time
with tf.device('/GPU:0'):
    neural_network = keras.wrappers.scikit_learn.KerasRegressor(build_fn = create_neural_network)

    # define parameters to search
    parameter_grid = {
        "batch_size": [16, 32],
        "epochs": [5],
        "shuffle": [True, False],
        "learning_rate": [0.001, 0.01],
        "verbose": [1]
    }

    k = 3
    grid = GridSearchCV(estimator = neural_network,
                        param_grid = parameter_grid,
                        scoring = ["neg_mean_squared_error", "r2"],
                        refit = "neg_mean_squared_error",
                        n_jobs = 1,
                        cv = k,
                        verbose = 3)


    # sample numpy array to search on subset of full dataset to speed search
    N0 = 0.01
    N = int(N0 * x_train.shape[0])
    sample_indices = np.random.choice(a = range(0, x_train.shape[0]), size = N, replace = False)

    # run grid search
    print(x_train.shape)
    print(x_train[sample_indices].shape)
    grid.fit(x_train[sample_indices], y_train[sample_indices])
# Out:
# C:\Users\leewi\AppData\Local\Temp\ipykernel_5728\4213043973.py:2: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   neural_network = keras.wrappers.scikit_learn.KerasRegressor(build_fn = create_neural_network)
# (10631136, 95)
# (106311, 95)
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# Epoch 1/5
# 4430/4430 [==============================] - 12s 2ms/step - loss: 3454.2424 - mean_squared_error: 3445.8115 - R2: -175.2127
# Epoch 2/5
# 4430/4430 [==============================] - 11s 2ms/step - loss: 13.9848 - mean_squared_error: 6.0901 - R2: 0.7084
# Epoch 3/5
# 4430/4430 [==============================] - 11s 2ms/step - loss: 12.7069 - mean_squared_error: 5.6714 - R2: 0.7261
# Epoch 4/5
# 4430/4430 [==============================] - 11s 2ms/step - loss: 11.7311 - mean_squared_error: 5.3922 - R2: 0.7387
# Epoch 5/5
# 4430/4430 [==============================] - 10s 2ms/step - loss: 11.0915 - mean_squared_error: 5.3470 - R2: 0.7402
# 2215/2215 [==============================] - 2s 709us/step
# [CV 1/3] END batch_size=16, epochs=5, learning_rate=0.001, shuffle=True, verbose=1; neg_mean_squared_error: (test=-5.135) r2: (test=0.783) total time=  56.8s
# Epoch 1/5
# 4430/4430 [==============================] - 11s 2ms/step - loss: 3251.5410 - mean_squared_error: 3244.4424 - R2: -163.6913
# Epoch 2/5
# 4430/4430 [==============================] - 11s 2ms/step - loss: 12.2568 - mean_squared_error: 5.7387 - R2: 0.7232
# Epoch 3/5
# 4430/4430 [==============================] - 11s 3ms/step - loss: 11.4080 - mean_squared_error: 5.5121 - R2: 0.7315
# Epoch 4/5
# 4430/4430 [==============================] - 11s 2ms/step - loss: 10.7612 - mean_squared_error: 5.3207 - R2: 0.7402
# Epoch 5/5
# 4430/4430 [==============================] - 11s 2ms/step - loss: 10.1365 - mean_squared_error: 5.0946 - R2: 0.7535
# 2215/2215 [==============================] - 2s 749us/step
# [CV 2/3] END batch_size=16, epochs=5, learning_rate=0.001, shuffle=True, verbose=1; neg_mean_squared_error: (test=-4.689) r2: (test=0.804) total time=  57.0s
# Epoch 1/5
# 4430/4430 [==============================] - 11s 2ms/step - loss: 3277.4363 - mean_squared_error: 3269.7527 - R2: -159.3470
# Epoch 2/5
# 4430/4430 [==============================] - 11s 2ms/step - loss: 14.0175 - mean_squared_error: 6.8240 - R2: 0.6741
# Epoch 3/5
# 4430/4430 [==============================] - 11s 2ms/step - loss: 12.8032 - mean_squared_error: 6.4288 - R2: 0.6884
# Epoch 4/5
# 4430/4430 [==============================] - 10s 2ms/step - loss: 11.8396 - mean_squared_error: 6.0573 - R2: 0.7041
# Epoch 5/5
# 4430/4430 [==============================] - 11s 2ms/step - loss: 11.0986 - mean_squared_error: 5.8385 - R2: 0.7140
# 2215/2215 [==============================] - 2s 736us/step
# [CV 3/3] END batch_size=16, epochs=5, learning_rate=0.001, shuffle=True, verbose=1; neg_mean_squared_error: (test=-5.231) r2: (test=0.783) total time=  57.0s
# Epoch 1/5
# 4430/4430 [==============================] - 11s 2ms/step - loss: 3333.4893 - mean_squared_error: 3325.2651 - R2: -175.1173
# Epoch 2/5
# 4430/4430 [==============================] - 11s 2ms/step - loss: 13.8042 - mean_squared_error: 6.1370 - R2: 0.7042
# Epoch 3/5
# 4430/4430 [==============================] - 11s 2ms/step - loss: 12.7215 - mean_squared_error: 5.7662 - R2: 0.7192
# Epoch 4/5
# 4430/4430 [==============================] - 10s 2ms/step - loss: 11.9446 - mean_squared_error: 5.6513 - R2: 0.7246
# Epoch 5/5
# 4430/4430 [==============================] - 11s 2ms/step - loss: 11.2894 - mean_squared_error: 5.5637 - R2: 0.7286
# 2215/2215 [==============================] - 2s 730us/step
# [CV 1/3] END batch_size=16, epochs=5, learning_rate=0.001, shuffle=False, verbose=1; neg_mean_squared_error: (test=-6.046) r2: (test=0.744) total time=  56.0s
# Epoch 1/5
# 4430/4430 [==============================] - 11s 2ms/step - loss: 3218.3367 - mean_squared_error: 3210.9094 - R2: -162.0311
# Epoch 2/5
# 4430/4430 [==============================] - 11s 2ms/step - loss: 13.3287 - mean_squared_error: 6.4731 - R2: 0.6885
# Epoch 3/5
# 4430/4430 [==============================] - 10s 2ms/step - loss: 12.1466 - mean_squared_error: 6.0417 - R2: 0.7081
# Epoch 4/5
# 4430/4430 [==============================] - 10s 2ms/step - loss: 11.2581 - mean_squared_error: 5.7039 - R2: 0.7238
# Epoch 5/5
# 4430/4430 [==============================] - 11s 2ms/step - loss: 10.5862 - mean_squared_error: 5.5037 - R2: 0.7329
# 2215/2215 [==============================] - 2s 744us/step
# [CV 2/3] END batch_size=16, epochs=5, learning_rate=0.001, shuffle=False, verbose=1; neg_mean_squared_error: (test=-6.607) r2: (test=0.724) total time=  55.4s
# Epoch 1/5
# 4430/4430 [==============================] - 11s 2ms/step - loss: 3448.0498 - mean_squared_error: 3440.3669 - R2: -174.0653
# Epoch 2/5
# 4430/4430 [==============================] - 10s 2ms/step - loss: 12.8730 - mean_squared_error: 5.8558 - R2: 0.7165
# Epoch 3/5
# 4430/4430 [==============================] - 10s 2ms/step - loss: 12.0563 - mean_squared_error: 5.7306 - R2: 0.7211
# Epoch 4/5
# 4430/4430 [==============================] - 11s 2ms/step - loss: 11.4276 - mean_squared_error: 5.6009 - R2: 0.7273
# Epoch 5/5
# 4430/4430 [==============================] - 10s 2ms/step - loss: 10.9147 - mean_squared_error: 5.5246 - R2: 0.7309
# 2215/2215 [==============================] - 2s 734us/step
# [CV 3/3] END batch_size=16, epochs=5, learning_rate=0.001, shuffle=False, verbose=1; neg_mean_squared_error: (test=-5.817) r2: (test=0.758) total time=  55.0s
# Epoch 1/5
# 4430/4430 [==============================] - 11s 2ms/step - loss: 584.5712 - mean_squared_error: 577.1378 - R2: -29.6126
# Epoch 2/5
# 4430/4430 [==============================] - 11s 3ms/step - loss: 23.7720 - mean_squared_error: 17.1315 - R2: 0.1354
# Epoch 3/5
# 4430/4430 [==============================] - 27s 6ms/step - loss: 19.0558 - mean_squared_error: 13.7773 - R2: 0.3154
# Epoch 4/5
# 4430/4430 [==============================] - 28s 6ms/step - loss: 16.5115 - mean_squared_error: 12.1893 - R2: 0.3883
# Epoch 5/5
# 4430/4430 [==============================] - 25s 6ms/step - loss: 14.3234 - mean_squared_error: 10.6095 - R2: 0.4793
# 2215/2215 [==============================] - 4s 2ms/step
# [CV 1/3] END batch_size=16, epochs=5, learning_rate=0.01, shuffle=True, verbose=1; neg_mean_squared_error: (test=-10.360) r2: (test=0.562) total time= 1.8min
# Epoch 1/5
# 4430/4430 [==============================] - 11s 2ms/step - loss: 547.4742 - mean_squared_error: 540.3156 - R2: -28.0639
# Epoch 2/5
# 4430/4430 [==============================] - 10s 2ms/step - loss: 23.1597 - mean_squared_error: 16.8830 - R2: 0.1531
# Epoch 3/5
# 4430/4430 [==============================] - 10s 2ms/step - loss: 19.1211 - mean_squared_error: 13.9774 - R2: 0.2976
# Epoch 4/5
# 4430/4430 [==============================] - 10s 2ms/step - loss: 16.6892 - mean_squared_error: 12.4294 - R2: 0.3793
# Epoch 5/5
# 4430/4430 [==============================] - 10s 2ms/step - loss: 14.6002 - mean_squared_error: 10.9506 - R2: 0.4543
# 2215/2215 [==============================] - 2s 706us/step
# [CV 2/3] END batch_size=16, epochs=5, learning_rate=0.01, shuffle=True, verbose=1; neg_mean_squared_error: (test=-8.987) r2: (test=0.624) total time=  55.0s
# Epoch 1/5
# 4430/4430 [==============================] - 11s 2ms/step - loss: 654.3387 - mean_squared_error: 646.4807 - R2: -31.9769
# Epoch 2/5
# 4430/4430 [==============================] - 10s 2ms/step - loss: 23.4877 - mean_squared_error: 16.9017 - R2: 0.1500
# Epoch 3/5
# 4430/4430 [==============================] - 11s 2ms/step - loss: 19.4809 - mean_squared_error: 14.3301 - R2: 0.2783
# Epoch 4/5
# 4430/4430 [==============================] - 11s 2ms/step - loss: 16.4463 - mean_squared_error: 12.1749 - R2: 0.3948
# Epoch 5/5
# 4430/4430 [==============================] - 11s 2ms/step - loss: 15.5806 - mean_squared_error: 11.8085 - R2: 0.4110
# 2215/2215 [==============================] - 2s 719us/step
# [CV 3/3] END batch_size=16, epochs=5, learning_rate=0.01, shuffle=True, verbose=1; neg_mean_squared_error: (test=-8.958) r2: (test=0.628) total time=  55.4s
# Epoch 1/5
# 4430/4430 [==============================] - 11s 2ms/step - loss: 475.9953 - mean_squared_error: 468.9044 - R2: -23.8947
# Epoch 2/5
# 4430/4430 [==============================] - 11s 3ms/step - loss: 25.5819 - mean_squared_error: 18.9355 - R2: 0.0456
# Epoch 3/5
# 4430/4430 [==============================] - 11s 2ms/step - loss: 21.0528 - mean_squared_error: 15.6119 - R2: 0.2162
# Epoch 4/5
# 4430/4430 [==============================] - 11s 2ms/step - loss: 17.8962 - mean_squared_error: 13.4161 - R2: 0.3296
# Epoch 5/5
# 4430/4430 [==============================] - 11s 2ms/step - loss: 15.5423 - mean_squared_error: 11.6736 - R2: 0.4146
# 2215/2215 [==============================] - 2s 720us/step
# [CV 1/3] END batch_size=16, epochs=5, learning_rate=0.01, shuffle=False, verbose=1; neg_mean_squared_error: (test=-12.103) r2: (test=0.489) total time=  56.8s
# Epoch 1/5
# 4430/4430 [==============================] - 11s 2ms/step - loss: 617.7880 - mean_squared_error: 609.6301 - R2: -30.9526
# Epoch 2/5
# 4430/4430 [==============================] - 10s 2ms/step - loss: 23.4995 - mean_squared_error: 16.6676 - R2: 0.1661
# Epoch 3/5
# 4430/4430 [==============================] - 10s 2ms/step - loss: 19.5543 - mean_squared_error: 14.1568 - R2: 0.2964
# Epoch 4/5
# 4430/4430 [==============================] - 10s 2ms/step - loss: 17.0875 - mean_squared_error: 12.5905 - R2: 0.3742
# Epoch 5/5
# 4430/4430 [==============================] - 10s 2ms/step - loss: 15.6999 - mean_squared_error: 11.7220 - R2: 0.4176
# 2215/2215 [==============================] - 2s 705us/step
# [CV 2/3] END batch_size=16, epochs=5, learning_rate=0.01, shuffle=False, verbose=1; neg_mean_squared_error: (test=-11.016) r2: (test=0.539) total time=  54.5s
# Epoch 1/5
# 4430/4430 [==============================] - 11s 2ms/step - loss: 598.1898 - mean_squared_error: 589.9514 - R2: -30.1001
# Epoch 2/5
# 4430/4430 [==============================] - 11s 2ms/step - loss: 24.6181 - mean_squared_error: 17.5171 - R2: 0.1137
# Epoch 3/5
# 4430/4430 [==============================] - 10s 2ms/step - loss: 20.8415 - mean_squared_error: 15.1371 - R2: 0.2382
# Epoch 4/5
# 4430/4430 [==============================] - 10s 2ms/step - loss: 18.4455 - mean_squared_error: 13.6603 - R2: 0.3160
# Epoch 5/5
# 4430/4430 [==============================] - 10s 2ms/step - loss: 16.8145 - mean_squared_error: 12.5325 - R2: 0.3742
# 2215/2215 [==============================] - 2s 726us/step
# [CV 3/3] END batch_size=16, epochs=5, learning_rate=0.01, shuffle=False, verbose=1; neg_mean_squared_error: (test=-12.134) r2: (test=0.496) total time=  55.6s
# Epoch 1/5
# 2215/2215 [==============================] - 6s 2ms/step - loss: 4631.4102 - mean_squared_error: 4624.0654 - R2: -214.6848
# Epoch 2/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 14.7921 - mean_squared_error: 7.4076 - R2: 0.6734
# Epoch 3/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 13.1119 - mean_squared_error: 6.0935 - R2: 0.7290
# Epoch 4/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 12.3321 - mean_squared_error: 5.7821 - R2: 0.7426
# Epoch 5/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 11.6209 - mean_squared_error: 5.5066 - R2: 0.7541
# 1108/1108 [==============================] - 1s 704us/step
# [CV 1/3] END batch_size=32, epochs=5, learning_rate=0.001, shuffle=True, verbose=1; neg_mean_squared_error: (test=-5.692) r2: (test=0.759) total time=  28.0s
# Epoch 1/5
# 2215/2215 [==============================] - 6s 2ms/step - loss: 6079.1382 - mean_squared_error: 6070.6367 - R2: -279.0473
# Epoch 2/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 15.9340 - mean_squared_error: 7.2196 - R2: 0.6785
# Epoch 3/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 13.7663 - mean_squared_error: 5.4606 - R2: 0.7572
# Epoch 4/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 12.9714 - mean_squared_error: 5.3293 - R2: 0.7606
# Epoch 5/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 12.2413 - mean_squared_error: 5.2445 - R2: 0.7659
# 1108/1108 [==============================] - 1s 714us/step
# [CV 2/3] END batch_size=32, epochs=5, learning_rate=0.001, shuffle=True, verbose=1; neg_mean_squared_error: (test=-4.869) r2: (test=0.796) total time=  27.5s
# Epoch 1/5
# 2215/2215 [==============================] - 6s 2ms/step - loss: 7139.4648 - mean_squared_error: 7130.7158 - R2: -316.1836
# Epoch 2/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 15.7788 - mean_squared_error: 6.9215 - R2: 0.6913
# Epoch 3/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 13.6499 - mean_squared_error: 5.3479 - R2: 0.7613
# Epoch 4/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 12.7566 - mean_squared_error: 5.1769 - R2: 0.7675
# Epoch 5/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 11.9398 - mean_squared_error: 5.0476 - R2: 0.7736
# 1108/1108 [==============================] - 1s 711us/step
# [CV 3/3] END batch_size=32, epochs=5, learning_rate=0.001, shuffle=True, verbose=1; neg_mean_squared_error: (test=-5.061) r2: (test=0.790) total time=  27.3s
# Epoch 1/5
# 2215/2215 [==============================] - 6s 2ms/step - loss: 5455.1440 - mean_squared_error: 5447.8721 - R2: -250.2239
# Epoch 2/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 13.7238 - mean_squared_error: 6.4299 - R2: 0.7154
# Epoch 3/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 12.4346 - mean_squared_error: 5.5282 - R2: 0.7547
# Epoch 4/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 11.9041 - mean_squared_error: 5.4862 - R2: 0.7558
# Epoch 5/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 11.2865 - mean_squared_error: 5.3238 - R2: 0.7629
# 1108/1108 [==============================] - 1s 709us/step
# [CV 1/3] END batch_size=32, epochs=5, learning_rate=0.001, shuffle=False, verbose=1; neg_mean_squared_error: (test=-4.783) r2: (test=0.798) total time=  28.0s
# Epoch 1/5
# 2215/2215 [==============================] - 6s 2ms/step - loss: 6555.6743 - mean_squared_error: 6547.2764 - R2: -313.2892
# Epoch 2/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 15.3906 - mean_squared_error: 6.8844 - R2: 0.6943
# Epoch 3/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 13.4930 - mean_squared_error: 5.4422 - R2: 0.7580
# Epoch 4/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 12.7029 - mean_squared_error: 5.3072 - R2: 0.7630
# Epoch 5/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 11.8773 - mean_squared_error: 5.1025 - R2: 0.7719
# 1108/1108 [==============================] - 1s 715us/step
# [CV 2/3] END batch_size=32, epochs=5, learning_rate=0.001, shuffle=False, verbose=1; neg_mean_squared_error: (test=-4.661) r2: (test=0.805) total time=  27.9s
# Epoch 1/5
# 2215/2215 [==============================] - 6s 2ms/step - loss: 8233.7529 - mean_squared_error: 8222.2900 - R2: -392.7791
# Epoch 2/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 18.6199 - mean_squared_error: 6.7446 - R2: 0.7010
# Epoch 3/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 17.3896 - mean_squared_error: 6.2883 - R2: 0.7212
# Epoch 4/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 16.4118 - mean_squared_error: 6.3547 - R2: 0.7178
# Epoch 5/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 15.3265 - mean_squared_error: 6.2778 - R2: 0.7210
# 1108/1108 [==============================] - 1s 718us/step
# [CV 3/3] END batch_size=32, epochs=5, learning_rate=0.001, shuffle=False, verbose=1; neg_mean_squared_error: (test=-6.224) r2: (test=0.741) total time=  27.4s
# Epoch 1/5
# 2215/2215 [==============================] - 6s 2ms/step - loss: 752.9849 - mean_squared_error: 745.3461 - R2: -33.4898
# Epoch 2/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 21.9338 - mean_squared_error: 15.0208 - R2: 0.3154
# Epoch 3/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 20.7001 - mean_squared_error: 14.4514 - R2: 0.3450
# Epoch 4/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 17.9471 - mean_squared_error: 12.5904 - R2: 0.4301
# Epoch 5/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 17.0872 - mean_squared_error: 12.4024 - R2: 0.4411
# 1108/1108 [==============================] - 1s 753us/step
# [CV 1/3] END batch_size=32, epochs=5, learning_rate=0.01, shuffle=True, verbose=1; neg_mean_squared_error: (test=-7.939) r2: (test=0.664) total time=  28.0s
# Epoch 1/5
# 2215/2215 [==============================] - 6s 2ms/step - loss: 1105.7739 - mean_squared_error: 1096.2645 - R2: -50.0176
# Epoch 2/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 19.6819 - mean_squared_error: 12.0576 - R2: 0.4532
# Epoch 3/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 19.3172 - mean_squared_error: 12.9810 - R2: 0.4114
# Epoch 4/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 16.6637 - mean_squared_error: 11.3633 - R2: 0.4833
# Epoch 5/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 15.7083 - mean_squared_error: 11.0596 - R2: 0.4999
# 1108/1108 [==============================] - 1s 713us/step
# [CV 2/3] END batch_size=32, epochs=5, learning_rate=0.01, shuffle=True, verbose=1; neg_mean_squared_error: (test=-11.956) r2: (test=0.500) total time=  27.4s
# Epoch 1/5
# 2215/2215 [==============================] - 6s 2ms/step - loss: 777.7296 - mean_squared_error: 769.6996 - R2: -32.0258
# Epoch 2/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 21.1163 - mean_squared_error: 13.8651 - R2: 0.3702
# Epoch 3/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 20.4193 - mean_squared_error: 13.9460 - R2: 0.3641
# Epoch 4/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 18.1517 - mean_squared_error: 12.5810 - R2: 0.4238
# Epoch 5/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 16.9367 - mean_squared_error: 12.0564 - R2: 0.4496
# 1108/1108 [==============================] - 1s 705us/step
# [CV 3/3] END batch_size=32, epochs=5, learning_rate=0.01, shuffle=True, verbose=1; neg_mean_squared_error: (test=-26.884) r2: (test=-0.117) total time=  28.8s
# Epoch 1/5
# 2215/2215 [==============================] - 6s 2ms/step - loss: 997.4007 - mean_squared_error: 988.8571 - R2: -47.4476
# Epoch 2/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 19.7464 - mean_squared_error: 12.5573 - R2: 0.4304
# Epoch 3/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 19.3241 - mean_squared_error: 13.0537 - R2: 0.4059
# Epoch 4/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 17.2155 - mean_squared_error: 11.8367 - R2: 0.4628
# Epoch 5/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 15.7868 - mean_squared_error: 11.1340 - R2: 0.4939
# 1108/1108 [==============================] - 1s 710us/step
# [CV 1/3] END batch_size=32, epochs=5, learning_rate=0.01, shuffle=False, verbose=1; neg_mean_squared_error: (test=-9.151) r2: (test=0.613) total time=  27.7s
# Epoch 1/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 1062.1799 - mean_squared_error: 1052.8826 - R2: -46.9854
# Epoch 2/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 19.9812 - mean_squared_error: 12.4584 - R2: 0.4360
# Epoch 3/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 19.3621 - mean_squared_error: 13.1296 - R2: 0.4028
# Epoch 4/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 16.7926 - mean_squared_error: 11.5827 - R2: 0.4730
# Epoch 5/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 15.5587 - mean_squared_error: 11.0102 - R2: 0.4996
# 1108/1108 [==============================] - 1s 720us/step
# [CV 2/3] END batch_size=32, epochs=5, learning_rate=0.01, shuffle=False, verbose=1; neg_mean_squared_error: (test=-9.695) r2: (test=0.594) total time=  26.9s
# Epoch 1/5
# 2215/2215 [==============================] - 6s 2ms/step - loss: 988.3351 - mean_squared_error: 980.3965 - R2: -43.7469
# Epoch 2/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 18.9913 - mean_squared_error: 12.2500 - R2: 0.4420
# Epoch 3/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 18.8697 - mean_squared_error: 12.9518 - R2: 0.4080
# Epoch 4/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 16.9941 - mean_squared_error: 11.9137 - R2: 0.4557
# Epoch 5/5
# 2215/2215 [==============================] - 5s 2ms/step - loss: 15.4815 - mean_squared_error: 11.0576 - R2: 0.4946
# 1108/1108 [==============================] - 1s 735us/step
# [CV 3/3] END batch_size=32, epochs=5, learning_rate=0.01, shuffle=False, verbose=1; neg_mean_squared_error: (test=-15.424) r2: (test=0.359) total time=  27.8s
# Epoch 1/5
# 6645/6645 [==============================] - 16s 2ms/step - loss: 2028.7516 - mean_squared_error: 2021.1919 - R2: -102.4236
# Epoch 2/5
# 6645/6645 [==============================] - 16s 2ms/step - loss: 13.2730 - mean_squared_error: 6.6861 - R2: 0.6786
# Epoch 3/5
# 6645/6645 [==============================] - 16s 2ms/step - loss: 12.0035 - mean_squared_error: 6.3181 - R2: 0.6930
# Epoch 4/5
# 6645/6645 [==============================] - 16s 2ms/step - loss: 11.1213 - mean_squared_error: 6.1524 - R2: 0.7021
# Epoch 5/5
# 6645/6645 [==============================] - 16s 2ms/step - loss: 10.5147 - mean_squared_error: 6.1128 - R2: 0.7038

# %%
print(grid.best_score_)
print(grid.best_params_)


filtered_params = {k: v for k, v in grid.best_params_.items() if k not in ('epochs', 'learning_rate', 'verbose')}
print(filtered_params)
# Out:
# -5.018557335383975
# {'batch_size': 16, 'epochs': 5, 'shuffle': True, 'verbose': 1, 'learning_rate': 0.001}
# {'batch_size': 16, 'shuffle': True}

# %%
# train whole model using cpu
with tf.device('/CPU:0'):
    # create early stopping callbacks
    callbacks_setup = [
        EarlyStopping(
            monitor="val_loss",        
            mode="min",
            patience=3,
            verbose=1,
            restore_best_weights=True
        ),
        ModelCheckpoint(
            "neural_network_group.keras",
            monitor="val_loss",        
            mode="min",
            save_best_only=True,
            verbose=1
        ),
    ]

    # fit the neural network on the whole dataset
    # validation_split makes neural network split into validation set so that validation scores may be measured throughout training
    neural_network_history = neural_network.fit(
        x_train,
        y_train,
        epochs = 20,
        validation_split=0.1,        
        callbacks=callbacks_setup,
        **filtered_params
    )
# Out:
# Epoch 1/20
# 597962/598002 [============================>.] - ETA: 0s - loss: 4.6441 - mean_squared_error: 3.7403 - R2: 0.8202
# Epoch 1: val_loss improved from inf to 4.85860, saving model to neural_network_group.keras
# 598002/598002 [==============================] - 451s 754us/step - loss: 4.6441 - mean_squared_error: 3.7403 - R2: 0.8203 - val_loss: 4.8586 - val_mean_squared_error: 4.0299 - val_R2: 0.8038
# Epoch 2/20
# 597954/598002 [============================>.] - ETA: 0s - loss: 4.3937 - mean_squared_error: 3.6093 - R2: 0.8271
# Epoch 2: val_loss improved from 4.85860 to 4.36592, saving model to neural_network_group.keras
# 598002/598002 [==============================] - 450s 753us/step - loss: 4.3937 - mean_squared_error: 3.6093 - R2: 0.8271 - val_loss: 4.3659 - val_mean_squared_error: 3.6189 - val_R2: 0.8260
# Epoch 3/20
# 597941/598002 [============================>.] - ETA: 0s - loss: 4.2621 - mean_squared_error: 3.5392 - R2: 0.8306
# Epoch 3: val_loss improved from 4.36592 to 4.04620, saving model to neural_network_group.keras
# 598002/598002 [==============================] - 451s 754us/step - loss: 4.2621 - mean_squared_error: 3.5393 - R2: 0.8306 - val_loss: 4.0462 - val_mean_squared_error: 3.3511 - val_R2: 0.8389
# Epoch 4/20
# 597957/598002 [============================>.] - ETA: 0s - loss: 4.1914 - mean_squared_error: 3.5149 - R2: 0.8317
# Epoch 4: val_loss did not improve from 4.04620
# 598002/598002 [==============================] - 449s 751us/step - loss: 4.1913 - mean_squared_error: 3.5148 - R2: 0.8317 - val_loss: 4.2137 - val_mean_squared_error: 3.5538 - val_R2: 0.8283
# Epoch 5/20
# 598000/598002 [============================>.] - ETA: 0s - loss: 4.1432 - mean_squared_error: 3.4983 - R2: 0.8324
# Epoch 5: val_loss improved from 4.04620 to 4.01956, saving model to neural_network_group.keras
# 598002/598002 [==============================] - 451s 754us/step - loss: 4.1432 - mean_squared_error: 3.4983 - R2: 0.8324 - val_loss: 4.0196 - val_mean_squared_error: 3.3881 - val_R2: 0.8371
# Epoch 6/20
# 597945/598002 [============================>.] - ETA: 0s - loss: 4.1043 - mean_squared_error: 3.4827 - R2: 0.8334
# Epoch 6: val_loss did not improve from 4.01956
# 598002/598002 [==============================] - 450s 752us/step - loss: 4.1043 - mean_squared_error: 3.4827 - R2: 0.8334 - val_loss: 4.1559 - val_mean_squared_error: 3.5365 - val_R2: 0.8304
# Epoch 7/20
# 597960/598002 [============================>.] - ETA: 0s - loss: 4.0842 - mean_squared_error: 3.4803 - R2: 0.8335
# Epoch 7: val_loss did not improve from 4.01956
# 598002/598002 [==============================] - 450s 753us/step - loss: 4.0842 - mean_squared_error: 3.4803 - R2: 0.8335 - val_loss: 4.0391 - val_mean_squared_error: 3.4431 - val_R2: 0.8346
# Epoch 8/20
# 597996/598002 [============================>.] - ETA: 0s - loss: 4.0635 - mean_squared_error: 3.4719 - R2: 0.8338Restoring model weights from the end of the best epoch: 5.
#
# Epoch 8: val_loss did not improve from 4.01956
# 598002/598002 [==============================] - 450s 752us/step - loss: 4.0635 - mean_squared_error: 3.4719 - R2: 0.8338 - val_loss: 4.1071 - val_mean_squared_error: 3.5236 - val_R2: 0.8303
# Epoch 8: early stopping

# %%
# plot the model history showing how training evolved over the epochs
hist = neural_network_history.history
callback_epoch = 5

# loss
plt.figure()
plt.plot(hist['loss'], label = 'Training')
plt.plot(hist['val_loss'], label = 'Validation')
plt.axvline(x=callback_epoch, linestyle='--', label=f'Best Epoch', color='green')
plt.title('ANN: Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# r2
plt.figure()
plt.plot(hist['R2'], label='Training')
plt.plot(hist['val_R2'], label = 'Validation')
plt.axvline(x=callback_epoch, linestyle='--', label=f'Best Epoch', color='green')
plt.title('ANN: Training and Validation R² Scores')
plt.xlabel('Epoch')
plt.ylabel('R²')
plt.legend()
plt.show()

# mse
plt.figure()
plt.plot(hist['mean_squared_error'], label = 'Training')
plt.plot(hist['val_mean_squared_error'], label = 'Validation')
plt.axvline(x=callback_epoch, linestyle='--',label=f'Best Epoch', color='green')
plt.title('ANN: Training and Validation Mean Squared Errors')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend()
plt.show()

# %% [markdown]
# #### 4. Evaluate Neural Network
# Measure model's performance on validation data.

# %%
# saves best model
neural_network.save("./")

# loads best model
final_neural_network = keras.models.load_model("neural_network_group.keras", custom_objects = {"R2": R2})

# %%
# want to evaluate metrics to measure the performance of model on data
y_train_predictions = final_neural_network.predict(x_train)
y_valid_predictions = final_neural_network.predict(x_valid)
# Out:
# 332223/332223 [==============================] - 253s 761us/step
# 83056/83056 [==============================] - 64s 767us/step

# %%
# calculate scores
# find rmse 
print(f"Training RMSE: {np.sqrt(mean_squared_error(y_train, y_train_predictions)):.4f}")
print(f"Validation RMSE: {np.sqrt(mean_squared_error(y_valid, y_valid_predictions)):.4f}")

# find r2 score
print(f"\nTraining R²: {r2_score(y_train, y_train_predictions):.4f}")
print(f"Validation R²: {r2_score(y_valid, y_valid_predictions):.4f}")

# find mae 
print(f"\nTraining MAE: {mean_absolute_error(y_train, y_train_predictions):.4f}")
print(f"Validation MAE: {mean_absolute_error(y_valid, y_valid_predictions):.4f}")
# Out:
# Training RMSE: 1.8408
# Validation RMSE: 1.8413
#
# Training R²: 0.8589
# Validation R²: 0.8587
#
# Training MAE: 1.3877
# Validation MAE: 1.3874

# %%
# save predictions
np.savetxt('nn_y_train_predictions.csv',
           y_train_predictions,
           delimiter=',',
           header='prediction',
           comments='')

np.savetxt('nn_y_valid_predictions.csv',
           y_valid_predictions,
           delimiter=',',
           header='prediction',
           comments='')

# %%
plt.figure(figsize=(12, 8))

# plot training and validation sets
plt.scatter(y_train, y_train_predictions, alpha=0.3, label='Training data', color='blue')
plt.scatter(y_valid, y_valid_predictions, alpha=0.5, label='Validation data', color='red')

# add straight line
plt.plot([y_valid.min(), y_valid.max()], [y_valid.min(), y_valid.max()], 
         'k--', lw=2, label='Perfect prediction (y=x)')

# add model trend line
bins = np.linspace(y_valid.min(), y_valid.max(), 20)
bin_means, bin_edges, _ = binned_statistic(y_valid, y_valid_predictions.ravel(), statistic = 'mean', bins = bins)
bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
plt.plot(bin_centers, bin_means, 'g-', lw=2, label='Average prediction trend')

# add metrics
plt.text(0.05, 0.95, f"Validation RMSE: {np.sqrt(mean_squared_error(y_valid, y_valid_predictions)):.2f}K\nR²: {r2_score(y_valid, y_valid_predictions):.3f}", 
         transform=plt.gca().transAxes, fontsize=12, 
         bbox=dict(facecolor='white', alpha=0.8))

plt.xlabel('Actual Temperature (K)', fontsize=12)
plt.ylabel('Predicted Temperature (K)', fontsize=12)
plt.title('ANN: Actual vs Predicted Temperature', fontsize=14)
plt.legend(loc='lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))

# plot training and validation
plt.scatter(y_train_predictions, y_train - y_train_predictions.ravel(), alpha=0.3, label='Training residuals', color='blue')
plt.scatter(y_valid_predictions, y_valid - y_valid_predictions.ravel(), alpha=0.5, label='Validation residuals', color='red')

# add straight line
plt.axhline(y=0, color='k', linestyle='--', label='Perfect prediction (residual=0)')

# add standard deviation lines
std_dev = np.std(y_valid - y_valid_predictions.ravel())
plt.axhline(y=std_dev, color='gray', linestyle='-.', alpha=0.5, label=f'+1 SD ({std_dev:.2f}K)')
plt.axhline(y=-std_dev, color='gray', linestyle='-.', alpha=0.5, label=f'-1 SD ({std_dev:.2f}K)')

# add residual line
bins = np.linspace(y_valid_predictions.min(), y_valid_predictions.max(), 20)
bin_means, bin_edges, _ = binned_statistic(y_valid_predictions.ravel(), y_valid - y_valid_predictions.ravel(), statistic='mean', bins=bins)
bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
plt.plot(bin_centers, bin_means, 'g-', lw=2, label='Average residual trend')

plt.xlabel('Predicted Temperature (K)', fontsize=12)
plt.ylabel('Residuals (K)', fontsize=12)
plt.title('ANN: Residuals Analysis', fontsize=14)
plt.legend(loc='upper right')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# histogram of residuals
plt.figure(figsize=(12, 6))
plt.hist(y_valid - y_valid_predictions.ravel(), bins=50, alpha=0.7)
plt.axvline(x=0, color='r', linestyle='--')
plt.xlabel('Residual Value (K)')
plt.ylabel('Frequency')
plt.title('ANN: Distribution of Residuals')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 2-1.5 Feature Importance
# Want to rank feature importance. Do this by proxy of neuron weights at input layer -- the neurons with the highest mean weight at this stage will be most relevant in finding the output of the network.

# %%
# finds weights at first layer
weight_0 = final_neural_network.layers[0].get_weights()[0]

# ranks the weights at the first layer
importance = np.mean(np.abs(weight_0), axis = 1)
sorted_importance = np.argsort(importance)[::-1]

# extract the top M features
M = 15
top_M = sorted_importance[:M][::-1]
feature_ranking = np.arange(len(top_M))

plt.figure(figsize = (16, 9))
plt.barh(feature_ranking, importance[top_M])
plt.yticks(feature_ranking, [f"{index}" for index in top_M])
plt.xlabel("Mean Weight")
plt.ylabel("Feature Index")
plt.title("ANN: Feature Importance (Determined by Weight at First Layer)")
plt.tight_layout()
plt.show()
